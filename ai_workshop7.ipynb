# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_dir='/content/drive/MyDrive/AI and ML/DevanagariHandwrittenDigitDataset'

# %% [markdown]
# 1. Dataset Preparation and Preprocessing:
# • Load the Devnagari dataset using PIL.
# • Normalize the images to the range [0, 1].
# • Reshape the images to include a channel dimension for Keras Compatibility.
# • Split the dataset into training and validation sets.
# • Add noise to the images for denoising purposes (Gaussian noise or salt-and-pepper noise).

# %% [markdown]
#  Import Necessary Libraries

# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %% [markdown]
# Configuration and Directory Setup

# %%
img_size = 32  # Based on Devnagari digit dataset
data_dir = '/content/drive/MyDrive/AI and ML/DevanagariHandwrittenDigitDataset'
train_dir = os.path.join(data_dir, 'Train')
test_dir = os.path.join(data_dir, 'Test')

# %% [markdown]
#  Load Images from Folders

# %%
def load_images_from_folder(folder):
    """
    Loads and preprocesses images from a given folder.

    Args:
    folder (str): Path to the folder containing subdirectories for each class.

    Returns:
    np.array: Array of processed image data.
    """
    images = []
    for class_name in os.listdir(folder):  # Iterate through each class folder
        class_path = os.path.join(folder, class_name)
        if os.path.isdir(class_path):  # Check if it's a directory (class folder)
            for img_file in os.listdir(class_path):  # Iterate through images in class folder
                if img_file.endswith('.png'):  # Check for PNG images
                    img_path = os.path.join(class_path, img_file)
                    img = Image.open(img_path).convert('L').resize((img_size, img_size))  # Open, convert to grayscale, resize
                    img_array = np.array(img, dtype=np.float32) / 255.0  # Normalize image to [0, 1]
                    images.append(img_array)  # Add processed image to the list
    return np.array(images)  # Return all images as a numpy array

# %% [markdown]
# Load and Preprocess Training and Testing Data

# %%
x_train = load_images_from_folder(train_dir)
x_test = load_images_from_folder(test_dir)

# %% [markdown]
#  Reshape Data for Keras

# %%
x_train = np.reshape(x_train, (-1, img_size, img_size, 1))
x_test = np.reshape(x_test, (-1, img_size, img_size, 1))

# %% [markdown]
#  Add Gaussian Noise to the Images

# %%
def add_gaussian_noise(images, noise_factor=0.5):
    """
    Add Gaussian noise to the input images.

    Args:
    images (np.array): Input images to which noise will be added.
    noise_factor (float): Standard deviation of the Gaussian noise.

    Returns:
    np.array: Noisy images, clipped to the [0, 1] range.
    """
    # Add Gaussian noise with the specified noise_factor to the images
    noisy = images + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=images.shape)
    return np.clip(noisy, 0., 1.)  # Clip the noisy images to ensure values stay within [0, 1]

# Add noise to the training and test datasets
x_train_noisy = add_gaussian_noise(x_train, noise_factor=0.5)
x_test_noisy = add_gaussian_noise(x_test, noise_factor=0.5)

# %% [markdown]
# Visualize a Few Sample Images

# %%
nn = 8  # Number of images to display

# Get random indices to display different images
random_indices = np.random.choice(len(x_train), nn, replace=False)

plt.figure(figsize=(12, 4))  # Set figure size for better visibility
for j, idx in enumerate(random_indices):
    # Display original image
    ax = plt.subplot(2, nn, j + 1)
    plt.imshow(x_train[idx].reshape(img_size, img_size), cmap='gray')  # Reshape image for proper display
    plt.title("Original")
    plt.axis('off')  # Turn off axis

    # Display noisy image
    ax = plt.subplot(2, nn, j + 1 + nn)
    plt.imshow(x_train_noisy[idx].reshape(img_size, img_size), cmap='gray')  # Display noisy version
    plt.title("Noisy")
    plt.axis('off')  # Turn off axis

plt.tight_layout()  # Adjust layout for better spacing
plt.show()  # Display the images

# %% [markdown]
# 2. Build the Denoising Convolutional Autoencoder:
# Build a convolutional autoencoder with at least 4 layers. The model should have an encoder to
# compress the input and a decoder to reconstruct the original image.
# • Use convolutional layers for the encoder and decoder.
# • Use ReLU activations for hidden layers and sigmoid for the output layer.
# Expected Deliverables:
# • A Complete rendered IPYTHON Notebook, with appropriate visualization and Results.

# %% [markdown]
# Encoder Section

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, UpSampling2D
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam

# %%
def build_encoder(input_shape=(32, 32, 1)):
    input_img = Input(shape=input_shape, name='input')

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(input_img)
    x = MaxPooling2D((2, 2), padding='same')(x)  # 16x16

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # 8x8

    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = MaxPooling2D((2, 2), padding='same')(x)  # 4x4

    encoded = Conv2D(256, (3, 3), activation='relu', padding='same', name='encoded')(x)  # 4x4x256

    return input_img, encoded

# %% [markdown]
# Decoder Section

# %%
def build_decoder(encoded_input):
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(encoded_input)
    x = UpSampling2D((2, 2))(x)  # 8x8

    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)  # 16x16

    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = UpSampling2D((2, 2))(x)  # 32x32

    decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same', name='decoded')(x)

    return decoded

# %% [markdown]
# Autoencoder Model

# %%
def build_autoencoder():
    """
    Build and compile an autoencoder model using separate encoder and decoder components.

    Returns:
    autoencoder (tf.keras.Model): The compiled autoencoder model.
    """
    # Build the encoder and get the encoded output
    input_img, encoded_output = build_encoder()

    # Build the decoder using the encoded output
    decoded_output = build_decoder(encoded_output)

    # Create the autoencoder model by combining encoder and decoder
    autoencoder = Model(inputs=input_img, outputs=decoded_output, name="autoencoder")

    # Compile the model with Adam optimizer and binary cross-entropy loss
    autoencoder.compile(optimizer=Adam(), loss='binary_crossentropy')

    return autoencoder

# %% [markdown]
# Model Summary

# %%
autoencoder = build_autoencoder()
autoencoder.summary()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)                   │ (None, 32, 32, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 8, 8, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 4, 4, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ encoded (Conv2D)                     │ (None, 4, 4, 256)           │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 4, 4, 128)           │         295,040 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d (UpSampling2D)         │ (None, 8, 8, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 8, 8, 64)            │          73,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_1 (UpSampling2D)       │ (None, 16, 16, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 16, 16, 32)          │          18,464 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ up_sampling2d_2 (UpSampling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoded (Conv2D)                     │ (None, 32, 32, 1)           │             289 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 775,425 (2.96 MB)
#  Trainable params: 775,425 (2.96 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 3. Train the Denoising Autoencoder:
# Train the model with the noisy images as inputs and the original images as targets. Monitor the training
# process by plotting the loss curves.

# %% [markdown]
# Training the Autoencoder

# %%
import matplotlib.pyplot as plt

# %%
history = autoencoder.fit(
    x_train_noisy, x_train,  # Noisy input → Clean output
    epochs=20,
    batch_size=128,
    shuffle=True,
    validation_data=(x_test_noisy, x_test)
)
# Out:
# Epoch 1/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 14s 49ms/step - loss: 0.4673 - val_loss: 0.2412
# Epoch 2/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.2214 - val_loss: 0.1872
# Epoch 3/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.1843 - val_loss: 0.1725
# Epoch 4/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.1707 - val_loss: 0.1644
# Epoch 5/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1633 - val_loss: 0.1607
# Epoch 6/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1584 - val_loss: 0.1558
# Epoch 7/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1550 - val_loss: 0.1542
# Epoch 8/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1527 - val_loss: 0.1537
# Epoch 9/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1503 - val_loss: 0.1510
# Epoch 10/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1488 - val_loss: 0.1505
# Epoch 11/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1474 - val_loss: 0.1483
# Epoch 12/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1456 - val_loss: 0.1485
# Epoch 13/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1445 - val_loss: 0.1477
# Epoch 14/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1437 - val_loss: 0.1469
# Epoch 15/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1427 - val_loss: 0.1452
# Epoch 16/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1419 - val_loss: 0.1455
# Epoch 17/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.1406 - val_loss: 0.1444
# Epoch 18/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 0.1399 - val_loss: 0.1462
# Epoch 19/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1398 - val_loss: 0.1442
# Epoch 20/20
# 133/133 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.1389 - val_loss: 0.1434

# %% [markdown]
# Plotting the Loss

# %%
# Plot training and validation loss over epochs
plt.plot(history.history['loss'], label='Training Loss')  # Plot training loss
plt.plot(history.history['val_loss'], label='Validation Loss')  # Plot validation loss

# Final touches to beautify the plot
plt.title('Training vs Validation Loss')  # Add title
plt.xlabel('Epoch')  # Label for the x-axis
plt.ylabel('Loss')  # Label for the y-axis
plt.legend()  # Display legend
plt.grid(True)  # Enable grid for better readability
plt.tight_layout()  # Adjust layout for better spacing
plt.show()  # Show the plot

# %% [markdown]
# 4. Evaluate and Visualize the Results:
# Evaluate the performance of the denoising autoencoder by visualizing a few noisy images, the denoised
# images generated by the model, and the original clean images.

# %%
# Number of images to display
n = 10

# Get random indices from the test set
random_indices = np.random.choice(len(x_test), n, replace=False)

# Predict denoised images using the same indices
denoised_images = autoencoder.predict(x_test_noisy[random_indices])

# Function to display noisy → denoised → original side by side
def plot_images(noisy, denoised, original, n=10):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Noisy Image
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(noisy[i].reshape(32, 32), cmap='gray')
        plt.title("Noisy")
        plt.axis('off')

        # Denoised Output
        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(denoised[i].reshape(32, 32), cmap='gray')
        plt.title("Denoised")
        plt.axis('off')

        # Original Clean Image
        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(original[i].reshape(32, 32), cmap='gray')
        plt.title("Original")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# Call the function using random samples
plot_images(x_test_noisy[random_indices], denoised_images, x_test[random_indices], n=n)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 914ms/step

# %% [markdown]
# 5. Experiment and Fine - Tune the Model:
# Try varying the model’s architecture, noise levels, or training parameters. Experiment with different
# numbers of layers, filters, and noise factors. Record your observations about how these changes affect
# the model’s performance.

# %%
# Function to get random samples and their predictions
def get_random_samples(noisy_data, clean_data, model, n=5):
    indices = np.random.choice(len(noisy_data), n, replace=False)
    noisy_samples = noisy_data[indices]
    clean_samples = clean_data[indices]
    denoised_samples = model.predict(noisy_samples)
    return noisy_samples, denoised_samples, clean_samples

# Function to plot noisy → denoised → original
def plot_images(noisy, denoised, original, n=5):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        ax = plt.subplot(3, n, i + 1)
        plt.imshow(noisy[i].reshape(32, 32), cmap='gray')
        plt.title("Noisy")
        plt.axis('off')

        ax = plt.subplot(3, n, i + 1 + n)
        plt.imshow(denoised[i].reshape(32, 32), cmap='gray')
        plt.title("Denoised")
        plt.axis('off')

        ax = plt.subplot(3, n, i + 1 + 2 * n)
        plt.imshow(original[i].reshape(32, 32), cmap='gray')
        plt.title("Original")
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# === USAGE ===
n = 5
noisy_samples, denoised_samples, clean_samples = get_random_samples(x_test_noisy, x_test, autoencoder, n=n)
plot_images(noisy_samples, denoised_samples, clean_samples, n=n)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 866ms/step
