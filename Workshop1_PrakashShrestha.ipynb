# %% [markdown]
# <a href="https://colab.research.google.com/github/prakash-2021/AI-herald/blob/main/Workshop1_PrakashShrestha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Introduction to Python Imaging Library(PIL)
#
# 2.1 Exercise - 1:
# Complete all the Task.
# 1. Read and display the image.
# • Read the image using the Pillow library and display it.
# • You can also use matplotlib to display the image.
# 2. Display only the top left corner of 100x100 pixels.
# • Extract the top-left corner of the image (100x100 pixels) and display it using NumPy and
# Array Indexing.
# 3. Show the three color channels (R, G, B).
# • Separate the image into its three color channels (Red, Green, and Blue) and display them
# individually, labeling each channel as R, G, and B.{Using NumPy.}
# 4. Modify the top 100 × 100 pixels to a value of 210 and display the resulting image:
# • Modify the pixel values of the top-left 100 × 100 region to have a value of 210 (which is a
# light gray color), and then display the modified image.

# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
img=Image.open('/content/assets/Lenna_(test_image).png')

# %%
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
import numpy as np

img_array = np.array(img)

top_left_100x100 = img_array[:100, :100]

plt.imshow(top_left_100x100)
plt.axis('off')
plt.show()

# %%
# Convert the Pillow image to a NumPy array
image_array_colored = np.array(img)

# Display the shape of the NumPy array (height, width, channels)
print("Shape of the image array:", image_array_colored.shape)

# For Red Channel
red_channel = image_array_colored[:, :, 0]  # Red channel
print("Red Channel:")
print(red_channel)

# Display the Red channel
plt.imshow(red_channel, cmap='Reds')
plt.axis('off')
plt.show()

# For Green Channel
green_channel = image_array_colored[:, :, 1]  # Green channel
print("Green Channel:")
print(green_channel)

# Display the Green channel
plt.imshow(green_channel, cmap='Greens')
plt.axis('off')
plt.show()

# For Blue Channel
blue_channel = image_array_colored[:, :, 2]  # Blue channel
print("Blue Channel:")
print(blue_channel)

# Display the Blue channel
plt.imshow(blue_channel, cmap='Blues')
plt.axis('off')
plt.show()
# Out:
# Shape of the image array: (512, 512, 3)
# Red Channel:
# [[226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  ...
#  [ 84  84  92 ... 173 172 177]
#  [ 82  82  96 ... 179 181 185]
#  [ 82  82  96 ... 179 181 185]]
# Green Channel:
# [[137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  [137 137 137 ... 148 130  99]
#  ...
#  [ 18  18  27 ...  73  68  62]
#  [ 22  22  32 ...  70  71  74]
#  [ 22  22  32 ...  70  71  74]]
# Blue Channel:
# [[125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  ...
#  [ 60  60  58 ...  84  76  79]
#  [ 57  57  62 ...  79  81  81]
#  [ 57  57  62 ...  79  81  81]]

# %%
# Modify the top-left 100x100 region to light gray (RGB = 210)
img_array[:100, :100] = [210, 210, 210]

# Convert back to an image and display
modified = Image.fromarray(img_array)

plt.imshow(modified)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# 2.2 Exercise - 2:
#
# Complete all the Task.
# 1. Load and display a grayscale image.
# • Load a grayscale image using the Pillow library.
# • Display the grayscale image using matplotlib.
# 2. Extract and display the middle section of the image (150 pixels).
# • Extract a 150 pixel section from the center of the image using NumPy array slicing.
# • Display this cropped image using matplotlib.
# 3. Apply a simple threshold to the image (e.g., set all pixel values below 100 to 0).
# • Apply a threshold to the grayscale image: set all pixel values below 100 to 0, and all values
# above 100 to 255 (creating a binary image).
# • Display the resulting binary image.
# 4. Rotate the image 90 degrees clockwise and display the result.
# • Rotate the image by 90 degrees clockwise using the Pillow rotate method or by manipulating
# the image array.
# • Display the rotated image using matplotlib.
# 5. Convert the grayscale image to an RGB image.
# • Convert the grayscale image into an RGB image where the grayscale values are replicated
# across all three channels (R, G, and B).
# • Display the converted RGB image using matplotlib.

# %%
img2 = Image.open('/content/assets/cameraman.png')

# Display the grayscale image
plt.imshow(img2, cmap='gray')
plt.title('Grayscale Image')
plt.axis('off')  # Turn off axis
plt.show()

# %%
img_array2 = np.array(img2)

center_x, center_y = img_array2.shape[1] // 2, img_array2.shape[0] // 2

cropped_image = img_array2[center_y - 75:center_y + 75, center_x - 75:center_x + 75]


plt.imshow(cropped_image, cmap='gray')
plt.title('Middle Section (150x150)')
plt.axis('off')
plt.show()

# %%
# Apply the threshold
binary_image = np.where(img_array2 < 100, 0, 255)

# Display the binary image
plt.imshow(binary_image, cmap='gray')
plt.title('Binary Image with Threshold')
plt.axis('off')
plt.show()

# %%
# Rotate the image by 90 degrees clockwise using NumPy (transpose and flip)
rotated_image = np.rot90(img_array2, k=-1)

# Display the rotated image
plt.imshow(rotated_image, cmap='gray')
plt.title('Rotated Image (90 degrees clockwise)')
plt.axis('off')
plt.show()

# %%
# Convert grayscale to RGB by replicating grayscale values across all three channels
rgb_image = np.stack([img_array2] * 3, axis=-1)

# Display the RGB image
plt.imshow(rgb_image)
plt.title('Converted RGB Image')
plt.axis('off')
plt.show()

# %% [markdown]
# 3 Image Compression and Decompression using PCA.
#
# In this exercise, build a PCA from scratch using explained variance method for image compression task.
# You are expected to compute the necessary matrices from the scratch. Dataset: Use image of your
# choice.
# 1. Load and Prepare Data:
#
# • Fetch an image of you choice.{If colour convert to grayscale}
#
# • Center the dataset - Standaridze the Data.
#
# • Calculate the covaraince matrix of the Standaridze data.
#
# 2. Eigen Decomposition and Identifying Principal Components:
#
# • Compute Eigen Values and Eigen Vectors.
#
# • Sort the eigenvalues in descending order and choose the top k eigenvectors corresponding to the highest eigenvalues.
#
# • Identify the Principal Components with the help of cumulative Sum plot.
#
# 3. Reconstruction and Experiment:
#
# • Reconstruction: Transform the original data by multiplying it with the selected eigenvec-
# tors(PCs) to obtain a lower-dimensional representation.
#
# • Experiments: Pick Four different combination of principal components with various ex-
# plained variance value and compare the result.
#
# • Display the Results and Evaluate.

# %%
img_path = '/content/assets/golden.png'
img3 = Image.open(img_path)

# Convert the image to grayscale (if it's a color image)
img3_gray = img3.convert('L')  # 'L' mode converts to grayscale

# Convert image to a NumPy array
image_arr3 = np.array(img3_gray)

# Visualize the original grayscale image
plt.imshow(image_arr3, cmap='gray')
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
# Standardize (center) the data (mean = 0, variance = 1)
scaler = StandardScaler()
image_data_centered = scaler.fit_transform(image_arr3)

# Covariance matrix
cov_matrix = np.cov(image_data_centered.T)

# %%
# Eigen decomposition (eigenvalues and eigenvectors)
eigenvalues, eigenvectors = np.linalg.eig(cov_matrix)

# Remove the imaginary part of eigenvalues and eigenvectors (if present)
eigenvalues = eigenvalues.real
eigenvectors = eigenvectors.real

# Sort eigenvalues and eigenvectors in descending order
sorted_indices = np.argsort(eigenvalues)[::-1]
sorted_eigenvalues = eigenvalues[sorted_indices]
sorted_eigenvectors = eigenvectors[:, sorted_indices]

# Plot the cumulative explained variance to select the number of components (k)
explained_variance_ratio = sorted_eigenvalues / np.sum(sorted_eigenvalues)
cumulative_variance = np.cumsum(explained_variance_ratio)

# Plotting cumulative explained variance
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance)
plt.xlabel('Number of Principal Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Explained Variance by Principal Components')
plt.show()

# Set the number of principal components
k = 50
# Select the top 'k' eigenvectors
top_k_eigenvectors = sorted_eigenvectors[:, :k]

# Project the data into the lower-dimensional space using the top 'k' eigenvectors
image_data_projected = np.dot(image_data_centered, top_k_eigenvectors)

# %%
# Project the image data onto the top k eigenvectors (lower-dimensional representation)
image_data_projected = np.dot(image_data_centered, top_k_eigenvectors)

# Reconstruct the image from the lower-dimensional representation
image_data_reconstructed = np.dot(image_data_projected, top_k_eigenvectors.T)

# If there are complex values, taking only the real part
image_data_reconstructed = np.real(image_data_reconstructed)

# Rescale the reconstructed data to match the original scale
image_data_reconstructed = scaler.inverse_transform(image_data_reconstructed)

# Display the reconstructed image
plt.imshow(image_data_reconstructed, cmap='gray')
plt.title(f'Reconstructed Image with {k} Principal Components')
plt.axis('off')
plt.show()

# %%
k_values = [5, 20, 50, 100]

for k in k_values:
    top_k_eigenvectors = sorted_eigenvectors[:, :k]

    # Project and reconstruct the image
    image_data_projected = np.dot(image_data_centered, top_k_eigenvectors)
    image_data_reconstructed = np.dot(image_data_projected, top_k_eigenvectors.T)
    image_data_reconstructed = image_data_reconstructed.real
    image_data_reconstructed = scaler.inverse_transform(image_data_reconstructed)

    # Display the reconstructed image
    plt.imshow(image_data_reconstructed, cmap='gray')
    plt.title(f'Reconstructed Image with {k} Principal Components')
    plt.axis('off')
    plt.show()
